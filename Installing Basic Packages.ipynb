# %% [markdown]
# ## Installing Miniconda3 with Pytorch
#
# This notebook will provide information necessary to install and set up your environment for writing and running code with Pytorch. We start by installing Anaconda, an open-source software useful for storing and managing Python libraries. We will install a mini light version for efficiency purposes available at [https://conda.io/miniconda.html](https://conda.io/miniconda.html).
#
# Find the right miniconda installation file corresponding to your computer's hardware and download the installer using the command below. Follow instructions to set up a folder in your home directory called /home/miniconda3. If you are not sure about your computer's microchip information, you can visit this [link](https://www.wikihow.com/Check-Your-Computer%27s-System-Information) to find out the right information using your operating system settings.

# %% [markdown]
# ### Installation
#
# Users of Mac-OS or Linux systems can use their Terminal application to install the 64-bit MiniConda.
#
# Downloading the installer for Intel CPU:
#
#     $ wget https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-x86_64.sh
#
# Downloading the installer for M# CPU:
#
#     $ wget https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-arm64.sh
#
# Run the installer and add the co
#
#     $ bash Miniconda3-latest-MacOSX-x86_64.sh
# or
#
#     $ bash Miniconda3-latest-MacOSX-arm64.sh
#
# Restart your terminal. You can also do the installation by double clicking on the installer in your operating system.
#
# In Windows, the user will need to either use a Linux Emulator, or download the Windows installer corresponding to their system in the list.

# %% [markdown]
# ### Verifying Installation
#
# After installing conda, you can verify your installation is up-to-date with the command:
#
#     $ conda update -n base conda -y
#
# Next, you should make sure conda has the pip tool that will help install any library inside the conda installation.
#
#     $ conda install pip -y
#
# To confirm that your environment is appropriately referencing your Miniconda installation you can use the following commands:
#
#     $ conda --version
#     # output: conda 23.5.2
#
#     $ which python
#     # output: /Users/dataman/miniconda3/bin/python

# %% [markdown]
# ### Creating Virtual Environment (Optional but Recommended)
#
# Check your current path (this is where your virtual environment will be installed)
#
#     $ pwd
#
# Create a virtual environment with name "FML26" (or anything you would like, just remember the name).
#
#     $ conda create -n FML26
#
# Activate the environment
#
#     $ conda activate FML26
#
# Deactivate the virtual environment when you are done using it
#
#     $ conda deactivate

# %% [markdown]
# ### Installing Packages
#
# We can now use the conda (base) environment to set up our Python projects.
#
# Install necessary packages (Jupyter, NumPy, Pandas, Matplotlib)
#
#     $ conda install jupyter numpy pandas matplotlib
#
# **Jupyter**: Interactive notebook.
#
# **Numpy**: Package for computations based on arrays, matrices, etc.
#
# **Pandas**: Managing tabular data.
#
# **Matplotlib**: making plots.
#
# Let's continue with installing and setting up [PyTorch](https://pytorch.org/get-started/locally/). On the webpage for PyTorch installation find the installation command for Python corresponding to your operating system. Choose conda for installation. On MacOS the command will be:
#
#     $ conda install pytorch torchvision -c pytorch
#
# Your computer should now be ready to start programming with Pytorch.

# %% [markdown]
# ### Launch Jupyter Notebook and Check Package Versions
#
# In your terminal, type (keep your virtual environment on if you installed in virtual environment):
#
#     $ jupyter notebook
#
# Create a new notebook, then copy and paste the following code block into the notebook to run.

# %%
import numpy, pandas, matplotlib, torch, torchvision

print('NumPy Version:', numpy.__version__)
print('Pandas Version:', pandas.__version__)
print('Matplotlib Version:', matplotlib.__version__)
print('Pytorch Version:', torch.__version__)
print('TorchVision Version:', torchvision.__version__)
# Out:
# NumPy Version: 2.4.6
# Pandas Version: 3.0.5
# Matplotlib Version: 3.11.0
# Pytorch Version: 2.13.0
# TorchVision Version: 0.28.0
